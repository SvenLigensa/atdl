# %% [markdown]
# # Setup (Download Grounding DINO Code and Model Weights)

# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
# %cd {HOME}
# !git clone https://github.com/IDEA-Research/GroundingDINO.git
# %cd {HOME}/GroundingDINO
# !pip install -q -e .

# %%
CONFIG_PATH = os.path.join(HOME, "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py")
print(CONFIG_PATH, "; exist:", os.path.isfile(CONFIG_PATH))

# %%
# %cd {HOME}
# !mkdir {HOME}/weights
# %cd {HOME}/weights

# !wget -q https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth

# %%
WEIGHTS_NAME = "groundingdino_swint_ogc.pth"
WEIGHTS_PATH = os.path.join(HOME, "weights", WEIGHTS_NAME)
print(WEIGHTS_PATH, "; exist:", os.path.isfile(WEIGHTS_PATH))

# %%
# %cd {HOME}/GroundingDINO

from groundingdino.util.inference import load_model, load_image, predict, annotate

model = load_model(CONFIG_PATH, WEIGHTS_PATH)

import supervision as sv

# %% [markdown]
# Give Model Access to Google Drive, so that we don't need to upload all the files one by one.

# %%
PATH_TO_DRIVE = "/content/drive/MyDrive/ColabNotebooks/NRW_Images_Small"

# %% [markdown]
# # Apply Grounding DINO

# %% [markdown]
# ## MLDE Group

# %%
IMAGE_NAME = "mlde_group.jpg"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "woman. man. wall. stones"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25
image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## "NO WAR"

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "no war"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "left peace sign"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "right peace sign"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "lettering"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "writing"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "no war text"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "no war text. without peace sign"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "peace"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "peace sign"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "peace sign. text without peace sign"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "sign. letter. letters" # Finds sign as *letter* and "NO WAR" as *letters*
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_354_5774_1_nw_2022_preprocessed_0_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "without peace sign"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Boats

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "rack"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "vessels"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water. rack"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "vessel"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "boat"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "boats"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water. boats"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water. vessels"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Boats (Bigger Input)

# %% [markdown]
# Setting both box and text threshold to $0$ produces $900$ (maximum number of) matches of whole phrase (`"water boat [SEP]"`).

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water . boat"
BOX_TRESHOLD = 0
TEXT_TRESHOLD = 0

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# Increasing the text threshold a little bit (to 1%), yields $900$ objects labeled as `""`, `"water"`, `"boat"`, and `"water boat"`.

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water . boat"
BOX_TRESHOLD = 0
TEXT_TRESHOLD = 0.01

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# But nearly all of the bounding boxes have a very low confidence (as expected).

# %%
import matplotlib.pyplot as plt

plt.scatter(list(range(900)), logits.sort()[0])

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "vessel"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "vessels"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_298_5750_1_nw_2022_preprocessed_29_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "boats"
BOX_TRESHOLD = 0.1
TEXT_TRESHOLD = 0.1

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Windmill

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "windmill"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "white windmill"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "wind wheel"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "turbine"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "windwheel"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "shadow"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_256_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "windmill shadow"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Windmill (Bigger Input)

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "windmill"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_510_5767_1_nw_2022_preprocessed_10_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "white windmill"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Hexagon Building

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "hexagon"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "rectangle"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "tree"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "top right tree"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "building"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# REC doesn't work: Top left building found.

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "bottom right building"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Orange Car

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "orange car"
BOX_TRESHOLD = 0.3
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "red car"
BOX_TRESHOLD = 0.3
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "white car"
BOX_TRESHOLD = 0.3
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_256_4.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "right car"
BOX_TRESHOLD = 0.3
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Orange Car (Bigger Input)

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "red car"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_512_3.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "orange car"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Tree Groups

# %%
IMAGE_NAME = "dop10rgbi_32_481_5752_1_nw_2022_preprocessed_18_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "tree"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_481_5752_1_nw_2022_preprocessed_18_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "bottom tree"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_481_5752_1_nw_2022_preprocessed_18_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "forest"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_481_5752_1_nw_2022_preprocessed_18_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "forest. trees. individual trees"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_481_5752_1_nw_2022_preprocessed_18_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "dirt road"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_481_5752_1_nw_2022_preprocessed_18_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "dirt road segments"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## White Trucks

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "truck"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "trucks"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "street"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "street. white car"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "street. white truck on street"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.1

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_527_5720_1_nw_2022_preprocessed_6_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "street. white truck"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.1

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Houses

# %%
IMAGE_NAME = "dop10rgbi_32_363_5710_1_nw_2022_preprocessed_2_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "house"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_363_5710_1_nw_2022_preprocessed_2_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "house"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.1

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_363_5710_1_nw_2022_preprocessed_2_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "houses"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Forest

# %%
IMAGE_NAME = "dop10rgbi_32_307_5693_1_nw_2022_preprocessed_20_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "street. forest. tree part of forest"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_307_5693_1_nw_2022_preprocessed_20_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "street. forest"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_307_5693_1_nw_2022_preprocessed_20_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "forest. street"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_307_5693_1_nw_2022_preprocessed_20_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "forest"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_307_5693_1_nw_2022_preprocessed_20_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "forest. treetop"
BOX_TRESHOLD = 0.1
TEXT_TRESHOLD = 0.5

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Bouncy Castle

# %%
IMAGE_NAME = "dop10rgbi_32_299_5684_1_nw_2022_preprocessed_19_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "rainbow"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_299_5684_1_nw_2022_preprocessed_19_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "bouncy castle"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Pool

# %%
IMAGE_NAME = "dop10rgbi_32_308_5673_1_nw_2022_preprocessed_8_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "pool"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_308_5673_1_nw_2022_preprocessed_8_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "blue circle"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_308_5673_1_nw_2022_preprocessed_8_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "light blue circle"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_308_5673_1_nw_2022_preprocessed_8_X_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "light blue circle"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_308_5673_1_nw_2022_preprocessed_8_X_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "pool"
BOX_TRESHOLD = 0.28
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Property
# - Can locate abstract term "property"

# %%
IMAGE_NAME = "dop10rgbi_32_315_5727_1_nw_2022_preprocessed_24_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "property"
BOX_TRESHOLD = 0.3
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Stream

# %%
IMAGE_NAME = "dop10rgbi_32_340_5752_1_nw_2022_preprocessed_5_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "stream"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_340_5752_1_nw_2022_preprocessed_5_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "brook"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_340_5752_1_nw_2022_preprocessed_5_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "creek"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_340_5752_1_nw_2022_preprocessed_5_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "river"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Tent

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "pavilion"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "gazebo"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "garden tent"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "tent"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "marquee"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "star"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "star shape"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "star shaped building"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_370_5721_1_nw_2022_preprocessed_4_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "building"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Graveyard

# %%
IMAGE_NAME = "dop10rgbi_32_425_5746_1_nw_2022_preprocessed_7_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "graveyard"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Houses (2)

# %%
IMAGE_NAME = "dop10rgbi_32_433_5724_1_nw_2022_preprocessed_27_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "houses"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Tree

# %%
IMAGE_NAME = "dop10rgbi_32_450_5764_1_nw_2022_preprocessed_3_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "tree"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Solar

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "solar panel"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "rooftops"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "rooftop"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "rooftops. solar panels on rooftops"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "solar plant"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "solarplant"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_492_5723_1_nw_2022_preprocessed_21_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "solar energy plant"
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Greenhouse (2)

# %%
IMAGE_NAME = "dop10rgbi_32_311_5697_1_nw_2022_preprocessed_28_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "greenhouse"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_311_5697_1_nw_2022_preprocessed_28_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "greenhouses"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Solar (2)

# %%
IMAGE_NAME = "dop10rgbi_32_388_5765_1_nw_2022_preprocessed_23_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "solar energy plant"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_388_5765_1_nw_2022_preprocessed_23_512_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "solar panel"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Helipad

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "helipad"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "heliport"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "circle"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "water"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "h"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_1024_1.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "letter"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))

# %% [markdown]
# ## Car

# %%
IMAGE_NAME = "dop10rgbi_32_460_5750_1_nw_2022_preprocessed_26_512_2.png"
IMAGE_PATH = os.path.join(HOME, PATH_TO_DRIVE, IMAGE_NAME)

TEXT_PROMPT = "car"
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

print(boxes.shape[0])
for i, x in enumerate(boxes):
  print(x, logits[i], phrases[i])

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# %matplotlib inline
sv.plot_image(annotated_frame, (16, 16))
